# %%
import pandas as pd

df = pd.read_csv('Biomass_History.csv')
df.head()
# Out:
#    Index  Latitude  Longitude       2010       2011       2012       2013  \
# 0      0  24.66818   71.33144   8.475744   8.868568   9.202181   6.023070
# 1      1  24.66818   71.41106  24.029778  28.551348  25.866415  21.634459
# 2      2  24.66818   71.49069  44.831635  66.111168  56.982258  53.003735
# 3      3  24.66818   71.57031  59.974419  80.821304  78.956543  63.160561
# 4      4  24.66818   71.64994  14.653370  19.327524  21.928144  17.899586
#
#         2014       2015       2016        2017
# 0  10.788374   6.647325   7.387925    5.180296
# 1  34.419411  27.361908  40.431847   42.126945
# 2  70.917908  42.517117  59.181629   73.203232
# 3  93.513924  70.203171  74.536720  101.067352
# 4  19.534035  19.165791  16.531315   26.086885

# %%
pip install geopandas
# Out:
# ...
#
#   Using cached geopandas-0.13.2-py3-none-any.whl (1.1 MB)
# ...
#      ---------------------------------------- 22.7/22.7 MB 9.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.8/5.8 MB 9.4 MB/s eta 0:00:00
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# ...

# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Longitude'],df['Latitude'])
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2010'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2011'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2012'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2013'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2014'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2015'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2016'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
sns.scatterplot(df['Longitude'],df['Latitude'],hue=df['2017'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>
